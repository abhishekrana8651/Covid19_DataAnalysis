# %% [markdown]
# # Analyze the Covid19 dataset

# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt 

print('Modules are imported.')
# Out:
# Modules are imported.

# %%
corona_dataset_csv = pd.read_csv('DataSet/covid19_Confirmed_dataset.csv')
corona_dataset_csv.head(10)
# Out:
#                  Province/State       Country/Region       Lat        Long  \
# 0                           NaN          Afghanistan  33.93911   67.709953
# 1                           NaN              Albania  41.15330   20.168300
# 2                           NaN              Algeria  28.03390    1.659600
# 3                           NaN              Andorra  42.50630    1.521800
# 4                           NaN               Angola -11.20270   17.873900
# 5                           NaN  Antigua and Barbuda  17.06080  -61.796400
# 6                           NaN            Argentina -38.41610  -63.616700
# 7                           NaN              Armenia  40.06910   45.038200
# 8  Australian Capital Territory            Australia -35.47350  149.012400
# 9               New South Wales            Australia -33.86880  151.209300
#
#    1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  9/25/21  \
# 0        0        0        0        0        0        0  ...   154960
# 1        0        0        0        0        0        0  ...   167354
# 2        0        0        0        0        0        0  ...   202574
# 3        0        0        0        0        0        0  ...    15167
# 4        0        0        0        0        0        0  ...    54795
# 5        0        0        0        0        0        0  ...     2902
# 6        0        0        0        0        0        0  ...  5249840
# 7        0        0        0        0        0        0  ...   257620
# 8        0        0        0        0        0        0  ...      874
# 9        0        0        0        0        3        4  ...    58931
#
#    9/26/21  9/27/21  9/28/21  9/29/21  9/30/21  10/1/21  10/2/21  10/3/21  \
# 0   154960   155072   155093   155128   155174   155191   155191   155191
# 1   167893   168188   168782   169462   170131   170778   171327   171794
# 2   202722   202877   203045   203198   203359   203517   203657   203789
# 3    15167    15189    15192    15209    15222    15222    15222    15222
# 4    55121    55583    56040    56583    56583    58076    58603    58943
# 5     2923     2923     3160     3188     3231     3336     3403     3503
# 6  5250402  5251940  5253765  5255261  5256902  5258466  5259352  5259738
# 7   258545   259007   259779   260675   261697   262631   263783   264690
# 8      893      906      928      959     1011     1063     1101     1129
# 9    59709    60561    61420    62353    63212    64014    64668    65279
#
#    10/4/21
# 0   155287
# 1   171794
# 2   203915
# 3    15267
# 4    58943
# 5     3503
# 6  5260719
# 7   265317
# 8     1162
# 9    65876
#
# [10 rows x 626 columns]

# %% [markdown]
# ### shape of the dataframe

# %%
corona_dataset_csv.shape
# Out:
# (279, 626)

# %% [markdown]
# ### Delete the useless columns

# %%
corona_dataset_csv.drop(['Lat','Long'],axis=1,inplace=True)
corona_dataset_csv.head(10)
# Out:
#                  Province/State       Country/Region  1/22/20  1/23/20  \
# 0                           NaN          Afghanistan        0        0
# 1                           NaN              Albania        0        0
# 2                           NaN              Algeria        0        0
# 3                           NaN              Andorra        0        0
# 4                           NaN               Angola        0        0
# 5                           NaN  Antigua and Barbuda        0        0
# 6                           NaN            Argentina        0        0
# 7                           NaN              Armenia        0        0
# 8  Australian Capital Territory            Australia        0        0
# 9               New South Wales            Australia        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  1/29/20  ...  9/25/21  \
# 0        0        0        0        0        0        0  ...   154960
# 1        0        0        0        0        0        0  ...   167354
# 2        0        0        0        0        0        0  ...   202574
# 3        0        0        0        0        0        0  ...    15167
# 4        0        0        0        0        0        0  ...    54795
# 5        0        0        0        0        0        0  ...     2902
# 6        0        0        0        0        0        0  ...  5249840
# 7        0        0        0        0        0        0  ...   257620
# 8        0        0        0        0        0        0  ...      874
# 9        0        0        3        4        4        4  ...    58931
#
#    9/26/21  9/27/21  9/28/21  9/29/21  9/30/21  10/1/21  10/2/21  10/3/21  \
# 0   154960   155072   155093   155128   155174   155191   155191   155191
# 1   167893   168188   168782   169462   170131   170778   171327   171794
# 2   202722   202877   203045   203198   203359   203517   203657   203789
# 3    15167    15189    15192    15209    15222    15222    15222    15222
# 4    55121    55583    56040    56583    56583    58076    58603    58943
# 5     2923     2923     3160     3188     3231     3336     3403     3503
# 6  5250402  5251940  5253765  5255261  5256902  5258466  5259352  5259738
# 7   258545   259007   259779   260675   261697   262631   263783   264690
# 8      893      906      928      959     1011     1063     1101     1129
# 9    59709    60561    61420    62353    63212    64014    64668    65279
#
#    10/4/21
# 0   155287
# 1   171794
# 2   203915
# 3    15267
# 4    58943
# 5     3503
# 6  5260719
# 7   265317
# 8     1162
# 9    65876
#
# [10 rows x 624 columns]

# %% [markdown]
# ###  Aggregating the rows by the country

# %%
corona_dataset_aggregated = corona_dataset_csv.groupby("Country/Region").sum()
corona_dataset_aggregated.tail(20)
# Out:
#                       1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# Country/Region
# Thailand                    4        4        5        6        8        8
# Timor-Leste                 0        0        0        0        0        0
# Togo                        0        0        0        0        0        0
# Trinidad and Tobago         0        0        0        0        0        0
# Tunisia                     0        0        0        0        0        0
# Turkey                      0        0        0        0        0        0
# US                          1        1        2        2        5        5
# Uganda                      0        0        0        0        0        0
# Ukraine                     0        0        0        0        0        0
# United Arab Emirates        0        0        0        0        0        0
# United Kingdom              0        0        0        0        0        0
# Uruguay                     0        0        0        0        0        0
# Uzbekistan                  0        0        0        0        0        0
# Vanuatu                     0        0        0        0        0        0
# Venezuela                   0        0        0        0        0        0
# Vietnam                     0        2        2        2        2        2
# West Bank and Gaza          0        0        0        0        0        0
# Yemen                       0        0        0        0        0        0
# Zambia                      0        0        0        0        0        0
# Zimbabwe                    0        0        0        0        0        0
#
#                       1/28/20  1/29/20  1/30/20  1/31/20  ...   9/25/21  \
# Country/Region                                            ...
# Thailand                   14       14       14       19  ...   1549285
# Timor-Leste                 0        0        0        0  ...     19350
# Togo                        0        0        0        0  ...     25163
# Trinidad and Tobago         0        0        0        0  ...     49822
# Tunisia                     0        0        0        0  ...    704914
# Turkey                      0        0        0        0  ...   7013609
# US                          5        6        6        8  ...  42900903
# Uganda                      0        0        0        0  ...    123066
# Ukraine                     0        0        0        0  ...   2495068
# United Arab Emirates        0        4        4        4  ...    734596
# United Kingdom              0        0        0        2  ...   7667290
# Uruguay                     0        0        0        0  ...    388424
# Uzbekistan                  0        0        0        0  ...    171588
# Vanuatu                     0        0        0        0  ...         4
# Venezuela                   0        0        0        0  ...    362040
# Vietnam                     2        2        2        2  ...    746678
# West Bank and Gaza          0        0        0        0  ...    395677
# Yemen                       0        0        0        0  ...      8891
# Zambia                      0        0        0        0  ...    208829
# Zimbabwe                    0        0        0        0  ...    129505
#
#                        9/26/21   9/27/21   9/28/21   9/29/21   9/30/21  \
# Country/Region
# Thailand               1561638   1571926   1581415   1591829   1603475
# Timor-Leste              19382     19398     19445     19455     19498
# Togo                     25218     25252     25323     25368     25429
# Trinidad and Tobago      49949     50055     50229     50459     50709
# Tunisia                 704914    705474    705474    706314    707190
# Turkey                 7039470   7066658   7095550   7124936   7154040
# US                    42931861  43116877  43226482  43349749  43460343
# Uganda                  123181    123245    123340    123445    123572
# Ukraine                2500198   2503710   2510781   2520986   2533301
# United Arab Emirates    734894    735180    735457    735727    735992
# United Kingdom         7700358   7737941   7772788   7808054   7843887
# Uruguay                 388502    388572    388700    388822    388928
# Uzbekistan              172090    172493    172899    173409    173895
# Vanuatu                      4         4         4         4         4
# Venezuela               362040    363300    366150    367672    368968
# Vietnam                 756689    766051    770640    779398    790755
# West Bank and Gaza      396746    398946    400649    402255    403716
# Yemen                     8934      8988      9016      9039      9067
# Zambia                  208857    208867    208912    209002    209046
# Zimbabwe                129625    129919    130272    130485    130820
#
#                        10/1/21   10/2/21   10/3/21   10/4/21
# Country/Region
# Thailand               1615229   1626604   1637432   1647362
# Timor-Leste              19535     19563     19582     19592
# Togo                     25429     25487     25535     25586
# Trinidad and Tobago      50903     51084     51243     51387
# Tunisia                 707548    707983    707983    708203
# Turkey                 7182913   7210886   7238237   7267047
# US                    43618627  43657833  43683048  43852255
# Uganda                  123742    123857    123976    124039
# Ukraine                2545904   2558300   2566875   2572327
# United Arab Emirates    736268    736524    736708    736897
# United Kingdom         7878571   7908091   7937810   7972312
# Uruguay                 389025    389124    389185    389260
# Uzbekistan              174408    174879    175267    175715
# Vanuatu                      4         4         4         4
# Venezuela               368968    370368    373332    373332
# Vietnam                 797712    803202    808578    813961
# West Bank and Gaza      405056    405780    406652    408211
# Yemen                     9111      9139      9139      9214
# Zambia                  209114    209142    209163    209172
# Zimbabwe                131028    131094    131129    131129
#
# [20 rows x 622 columns]

# %%
corona_dataset_aggregated.shape
# Out:
# (195, 622)

# %% [markdown]
# ### Visualizing data related to a country

# %%
corona_dataset_aggregated.loc['China'].plot()
corona_dataset_aggregated.loc['India'].plot()
corona_dataset_aggregated.loc['US'].plot()

plt.legend()

# %% [markdown]
# ### Calculating a good measure
# we need to find a good measure reperestend as a number, describing the spread of the virus in a country

# %%
corona_dataset_aggregated.loc['India'].plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### caculating the first derivative of the curve

# %%
corona_dataset_aggregated.loc['India'].diff().plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### find maxmimum infection rate for China

# %%
corona_dataset_aggregated.loc['China'].diff().max()
# Out:
# 15136.0

# %%
corona_dataset_aggregated.loc['India'].diff().max()
# Out:
# 414188.0

# %%
corona_dataset_aggregated.loc['US'].diff().max()
# Out:
# 303008.0

# %% [markdown]
# ### find maximum infection rate for all of the countries

# %%
countries = list(corona_dataset_aggregated.index)
max_infection_rates = []
for country in countries :
    max_infection_rates.append(corona_dataset_aggregated.loc[country].diff().max())
corona_dataset_aggregated['max infection rate'] = max_infection_rates

# %%
corona_dataset_aggregated.head()
# Out:
#                 1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  \
# Country/Region
# Afghanistan           0        0        0        0        0        0        0
# Albania               0        0        0        0        0        0        0
# Algeria               0        0        0        0        0        0        0
# Andorra               0        0        0        0        0        0        0
# Angola                0        0        0        0        0        0        0
#
#                 1/29/20  1/30/20  1/31/20  ...  9/26/21  9/27/21  9/28/21  \
# Country/Region                             ...
# Afghanistan           0        0        0  ...   154960   155072   155093
# Albania               0        0        0  ...   167893   168188   168782
# Algeria               0        0        0  ...   202722   202877   203045
# Andorra               0        0        0  ...    15167    15189    15192
# Angola                0        0        0  ...    55121    55583    56040
#
#                 9/29/21  9/30/21  10/1/21  10/2/21  10/3/21  10/4/21  \
# Country/Region
# Afghanistan      155128   155174   155191   155191   155191   155287
# Albania          169462   170131   170778   171327   171794   171794
# Algeria          203198   203359   203517   203657   203789   203915
# Andorra           15209    15222    15222    15222    15222    15267
# Angola            56583    56583    58076    58603    58943    58943
#
#                 max infection rate
# Country/Region
# Afghanistan                 3243.0
# Albania                     1239.0
# Algeria                     1927.0
# Andorra                      299.0
# Angola                      1493.0
#
# [5 rows x 623 columns]

# %% [markdown]
# ### create a new dataframe with only needed column

# %%
corona_data = pd.DataFrame(corona_dataset_aggregated['max infection rate'])
corona_data.head(10)
# Out:
#                      max infection rate
# Country/Region
# Afghanistan                      3243.0
# Albania                          1239.0
# Algeria                          1927.0
# Andorra                           299.0
# Angola                           1493.0
# Antigua and Barbuda               299.0
# Argentina                       41080.0
# Armenia                          2476.0
# Australia                        2400.0
# Austria                          9586.0

# %% [markdown]
# ### importing the dataset

# %%
world_happiness_report = pd.read_csv("DataSet/worldwide_happiness_report.csv")
world_happiness_report.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# 2                      0.341
# 3                      0.118
# 4                      0.298

# %%
world_happiness_report.shape
# Out:
# (156, 9)

# %% [markdown]
# ### drop the useless columns

# %%
columns_to_dropped = ['Overall rank','Score','Generosity','Perceptions of corruption']
world_happiness_report.drop(columns_to_dropped,axis=1 , inplace=True)
world_happiness_report.head()
# Out:
#   Country or region  GDP per capita  Social support  Healthy life expectancy  \
# 0           Finland           1.340           1.587                    0.986
# 1           Denmark           1.383           1.573                    0.996
# 2            Norway           1.488           1.582                    1.028
# 3           Iceland           1.380           1.624                    1.026
# 4       Netherlands           1.396           1.522                    0.999
#
#    Freedom to make life choices
# 0                         0.596
# 1                         0.592
# 2                         0.603
# 3                         0.591
# 4                         0.557

# %% [markdown]
# ### changing the indices of the dataframe

# %%
world_happiness_report.set_index(['Country or region'],inplace=True)
world_happiness_report.head()
# Out:
#                    GDP per capita  Social support  Healthy life expectancy  \
# Country or region
# Finland                     1.340           1.587                    0.986
# Denmark                     1.383           1.573                    0.996
# Norway                      1.488           1.582                    1.028
# Iceland                     1.380           1.624                    1.026
# Netherlands                 1.396           1.522                    0.999
#
#                    Freedom to make life choices
# Country or region
# Finland                                   0.596
# Denmark                                   0.592
# Norway                                    0.603
# Iceland                                   0.591
# Netherlands                               0.557

# %% [markdown]
# ### join two dataset we have prepared

# %%
corona_data.head()
# Out:
#                 max infection rate
# Country/Region
# Afghanistan                 3243.0
# Albania                     1239.0
# Algeria                     1927.0
# Andorra                      299.0
# Angola                      1493.0

# %%
world_happiness_report.head()
# Out:
#                    GDP per capita  Social support  Healthy life expectancy  \
# Country or region
# Finland                     1.340           1.587                    0.986
# Denmark                     1.383           1.573                    0.996
# Norway                      1.488           1.582                    1.028
# Iceland                     1.380           1.624                    1.026
# Netherlands                 1.396           1.522                    0.999
#
#                    Freedom to make life choices
# Country or region
# Finland                                   0.596
# Denmark                                   0.592
# Norway                                    0.603
# Iceland                                   0.591
# Netherlands                               0.557

# %%
data = world_happiness_report.join(corona_data).copy()
data.head()
# Out:
#                    GDP per capita  Social support  Healthy life expectancy  \
# Country or region
# Finland                     1.340           1.587                    0.986
# Denmark                     1.383           1.573                    0.996
# Norway                      1.488           1.582                    1.028
# Iceland                     1.380           1.624                    1.026
# Netherlands                 1.396           1.522                    0.999
#
#                    Freedom to make life choices  max infection rate
# Country or region
# Finland                                   0.596              1322.0
# Denmark                                   0.592              4508.0
# Norway                                    0.603              1785.0
# Iceland                                   0.591               170.0
# Netherlands                               0.557             13072.0

# %% [markdown]
# ### Visualization of the results

# %%
data.head()
# Out:
#                    GDP per capita  Social support  Healthy life expectancy  \
# Country or region
# Finland                     1.340           1.587                    0.986
# Denmark                     1.383           1.573                    0.996
# Norway                      1.488           1.582                    1.028
# Iceland                     1.380           1.624                    1.026
# Netherlands                 1.396           1.522                    0.999
#
#                    Freedom to make life choices  max infection rate
# Country or region
# Finland                                   0.596              1322.0
# Denmark                                   0.592              4508.0
# Norway                                    0.603              1785.0
# Iceland                                   0.591               170.0
# Netherlands                               0.557             13072.0

# %% [markdown]
# ### Plotting GDP vs maximum Infection rate

# %%
x = data['GDP per capita']
y = data['max infection rate']
sns.scatterplot(x,np.log(y))
# Out:
# <AxesSubplot:xlabel='GDP per capita', ylabel='max infection rate'>

# %% [markdown]
# ###  Plotting Social support vs maximum Infection rate

# %%
x = data['Social support']
y = data['max infection rate']
sns.scatterplot(x,np.log(y))
# Out:
# <AxesSubplot:xlabel='Social support', ylabel='max infection rate'>

# %% [markdown]
# ###  Plotting Healthy life expectancy vs maximum Infection rate

# %%
x = data['Healthy life expectancy']
y = data['max infection rate']
sns.scatterplot(x,np.log(y))
# Out:
# <AxesSubplot:xlabel='Healthy life expectancy', ylabel='max infection rate'>

# %% [markdown]
# ### Plotting Freedom to make life choices vs maximum Infection rate

# %%
x = data['Freedom to make life choices']
y = data['max infection rate']
sns.scatterplot(x,np.log(y))
# Out:
# <AxesSubplot:xlabel='Freedom to make life choices', ylabel='max infection rate'>
